# %% [markdown]
# ## Part 1 - data visualization

# %% [markdown]
# #### Preliminaries

# %% [markdown]
# First we import the libraries we will need, and the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as spst, scipy.spatial as sp, scipy.cluster.hierarchy as hc
import seaborn as sns
from biokit.viz import corrplot, heatmap
import dcor
import copy

# %% [markdown]
# #### Data loading and inspection

# %% [markdown]
# The data (public) is from the paper **Many correlation coefficients, null hypoteses, and high value (Hunt, 2013, Reference 1)**; I used it previously in  my [Geoscience ML notebook 2](https://github.com/mycarta/predict/blob/master/Geoscience_ML_notebook_2.ipynb)
# The dependent variable to be predicted, Y, is oil production (measured in tens of barrels of oil per day) from a marine barrier sand.
# Independent variables are:
#
# - Gross pay in meters
#
# - Phi-h, with a 3% porosity cut-off
#
# - Position in the reservoir. This is a ranked variable where a value close to 1 means the upper reservoir facies, a value close to 2 means the middle reservoir facies, and a value close to 3 means the lower reservoir facies.
#
# - Pressure drawdown in MPa.
#
# - 2 random variables
#
# - 1 variable added by me (see my [Geoscience ML support notebook](https://github.com/mycarta/predict/blob/master/Geoscience_ML_support_for_notebook_2.ipynb)) as a log transform of Gross pay to simulate extremely highly correlated independent variables.

# %%
data = pd.read_csv('../data/Table2_Hunt_2013_edit.csv')

# %%
data
# Out:
#     Gross pay  Phi-h  Position  Pressure  Random 1  Random 2  \
# 0         0.1    0.5       2.1        19         5       379
# 1         1.0    4.0       1.1        16        13       269
# 2         1.9   19.0       1.0        14        12       245
# 3         3.1   21.7       2.1        17         6       273
# 4         4.1   24.6       2.9        11        10       237
# 5         4.9   39.2       1.1        12         7       278
# 6         5.9   23.6       2.1        13        13       241
# 7         7.0   63.0       2.0        13        20       269
# 8         8.1   72.9       2.9        14         1       248
# 9         8.9   35.6       2.8        16         1       210
# 10       10.0  100.0       2.2        16        21       334
# 11       11.1   77.7       2.0        14         1       340
# 12       11.9   71.4       2.9        20        11       224
# 13       13.0  117.0       1.1        16         9       338
# 14       14.1  141.0       1.2        14        10       367
# 15       15.1  105.7       1.0        17         3       363
# 16       15.9   79.5       1.1        20        10       395
# 17       16.0  160.0       1.2        17        15       295
# 18       17.1   85.5       1.9        14         6       266
# 19       18.0   90.0       2.8        18        19       210
# 20       19.1  114.6       2.1        10        21       366
#
#     Gross pay transform  Production
# 0                  3.54       15.10
# 1                  5.79       21.30
# 2                  8.51       22.75
# 3                 11.52       15.72
# 4                 10.16        7.71
# 5                 11.14       22.67
# 6                 15.04       18.11
# 7                 15.10       24.30
# 8                 14.49       24.04
# 9                 16.90       25.11
# 10                16.61       36.80
# 11                17.81       36.42
# 12                19.74       39.59
# 13                17.70       51.60
# 14                19.16       48.05
# 15                21.97       51.72
# 16                22.15       59.20
# 17                24.24       58.30
# 18                23.58       41.80
# 19                23.77       44.20
# 20                29.25       37.51

# %% [markdown]
# We can print a list of the variables.

# %%
print (list(data))
# Out:
# ['Gross pay', 'Phi-h', 'Position', 'Pressure', 'Random 1', 'Random 2', 'Gross pay transform', 'Production']

# %% [markdown]
# We can rearrange variable columns, then print a summary of the data and compare the row count to show there are no missing data points.

# %%
data = data.loc[:, ['Position', 'Gross pay', 'Phi-h', 'Pressure', 'Random 1', 'Random 2', 'Gross pay transform', 'Production']]
data.describe()
# Out:
#         Position  Gross pay       Phi-h   Pressure   Random 1    Random 2  \
# count  21.000000  21.000000   21.000000  21.000000  21.000000   21.000000
# mean    1.885714   9.823810   68.880952  15.285714  10.190476  292.714286
# std     0.708721   5.948521   45.167894   2.759400   6.439092   59.429069
# min     1.000000   0.100000    0.500000  10.000000   1.000000  210.000000
# 25%     1.100000   4.900000   24.600000  14.000000   6.000000  245.000000
# 50%     2.000000  10.000000   72.900000  16.000000  10.000000  273.000000
# 75%     2.200000  15.100000  100.000000  17.000000  13.000000  340.000000
# max     2.900000  19.100000  160.000000  20.000000  21.000000  395.000000
#
#        Gross pay transform  Production
# count            21.000000   21.000000
# mean             16.579524   33.428571
# std               6.543793   15.141909
# min               3.540000    7.710000
# 25%              11.520000   22.670000
# 50%              16.900000   36.420000
# 75%              21.970000   44.200000
# max              29.250000   59.200000

# %% [markdown]
# We can also explicitly test to ensure data does not have no missing measurements.

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Visualization with a custom correlation matrix

# %% [markdown]
# https://blog.datadive.net/selecting-good-features-part-i-univariate-selection/
#
# "While for Pearson correlation, the correlation value 0 does not imply independence (as we saw from the x vs x2 example), distance correlation of 0 does imply that there is no dependence between the two variables."

# %% [markdown]
# Distance correlation p-value like Thomas, using `dcor.independence.distance_covariance_test` see equivalence below:

# %% [markdown]
# https://dcor.readthedocs.io/en/latest/energycomparison.html

# %% [raw]
# print (dcor.distance_correlation(data['Production'], data['Gross pay']))
# print(dcor.independence.distance_covariance_test(data['Production'], data['Gross pay'], exponent=1.0, num_resamples=2000))

# %% [raw]
# print (dcor.distance_correlation(data['Production'], data['Phi-h']))
# print(dcor.independence.distance_covariance_test(data['Production'], data['Phi-h'], exponent=1.0, num_resamples=2000))

# %% [raw]
# print (dcor.distance_correlation(data['Production'], data['Position']))
# print(dcor.independence.distance_covariance_test(data['Production'], data['Position'], exponent=1.0, num_resamples=2000))

# %% [raw]
# print (dcor.distance_correlation(data['Production'], data['Pressure']))
# print(dcor.independence.distance_covariance_test(data['Production'], data['Pressure'], exponent=1.0, num_resamples=2000))

# %% [raw]
# print (dcor.distance_correlation(data['Production'], data['Random 1']))
# print(dcor.independence.distance_covariance_test(data['Production'], data['Random 1'], exponent=1.0, num_resamples=2000))

# %% [raw]
# print (dcor.distance_correlation(data['Production'], data['Random 2']))
# print(dcor.independence.distance_covariance_test(data['Production'], data['Random 2'], exponent=1.0, num_resamples=2000))

# %%
def dist_corr(X, Y, pval=True, nruns=2000):
    """ Distance correlation with p-value from bootstrapping
    """
    dc = dcor.distance_correlation(X, Y)
    pv = dcor.independence.distance_covariance_test(X, Y, exponent=1.0, num_resamples=nruns)[0]

    if pval:
        return (dc, pv)
    else:
        return dc

# %%
def corrfunc(x, y, **kws):
    d, p = dist_corr(x,y) 
    #print("{:.4f}".format(d), "{:.4f}".format(p))
    if p > 0.1:
        pclr = 'Darkgray'
    else:
        pclr= 'Darkblue'
    ax = plt.gca()
    #ax.annotate("p-value = {:.5f}".format(p), xy=(.1, 0.998), xycoords=ax.transAxes, color = pclr, fontsize = 14)
    ax.annotate("DC = {:.2f}".format(d), xy=(.1, 0.99), xycoords=ax.transAxes, color = pclr, fontsize = 14)

# %% [markdown]
# plt.rcParams["axes.labelsize"] = 18
# g = sns.PairGrid(data, diag_sharey=False)
# axes = g.axes
#
# g.map_upper(plt.scatter,  linewidths=1, edgecolor="w", s=90, alpha = 0.5)
# g.map_upper(corrfunc)
#
# g.map_diag(sns.kdeplot, lw = 4, legend=False)
# g.map_lower(sns.kdeplot, cmap="Blues_d")
#
# #plt.savefig('matrix_final.png', dpi=500, bbox_inches='tight', pad_inches=0.1)
# plt.show()

# %% [markdown]
# #### Clustering of independent variables only.
#
# #### Using the [Biokit library](https://github.com/biokit/biokit/blob/master/notebooks/viz/corrplot.ipynb).

# %% [markdown]
# Baaed on:
#
# - distance correlation
#
# Displays bivariate ellipses in the lower triangle:
# - ellipticity is proportional to the correlation coefficient
# - direction and colour indicate whether positive or negative correlation

# %% [markdown]
# Notice that the correlation matrix is reordered by clustering correlated variables to facilitate interpretation.
# The more interestign ones are close to the diagonal.
#
#
# Read more here:
#
# - https://blogs.sas.com/content/iml/2018/05/02/reorder-variables-correlation-heat-map.html
# - https://cran.r-project.org/web/packages/corrplot/vignettes/corrplot-intro.html
# - https://github.com/biokit/biokit/blob/master/biokit/viz/corrplot.py

# %% [markdown]
# #### Distance correlation

# %% [markdown]
# Distance correlation from the [dcor library](https://github.com/vnmabus/dcor) and applied using a modification from [this SO answer on Euclidean distance](https://stackoverflow.com/a/29731899/1034648)

# %%
data=data.drop(columns=['Production'])

# %%
distcorr = lambda column1, column2: dcor.distance_correlation(column1, column2)
rslt = data.apply(lambda col1: data.apply(lambda col2: distcorr(col1, col2)))
pd.options.display.float_format = '{:,.2f}'.format
rslt
# Out:
#                      Position  Gross pay  Phi-h  Pressure  Random 1  Random 2  \
# Position                 1.00       0.28   0.32      0.22      0.32      0.54
# Gross pay                0.28       1.00   0.89      0.34      0.32      0.45
# Phi-h                    0.32       0.89   1.00      0.27      0.35      0.54
# Pressure                 0.22       0.34   0.27      1.00      0.27      0.31
# Random 1                 0.32       0.32   0.35      0.27      1.00      0.23
# Random 2                 0.54       0.45   0.54      0.31      0.23      1.00
# Gross pay transform      0.23       0.97   0.83      0.38      0.35      0.39
#
#                      Gross pay transform
# Position                            0.23
# Gross pay                           0.97
# Phi-h                               0.83
# Pressure                            0.38
# Random 1                            0.35
# Random 2                            0.39
# Gross pay transform                 1.00

# %%
c1 = corrplot.Corrplot(rslt)

# %%
c1.plot(method='ellipse', cmap='Dark2_r', shrink=1, rotation=45)
fig = plt.gcf()
fig.set_size_inches(10, 8)
plt.gcf().get_axes()[0].invert_yaxis();
#plt.savefig('103_05-12_ellipses_cc_all_curv1.png', dpi=500, bbox_inches='tight', pad_inches=0.2)

# %%
c1.plot(method='rectangle', cmap='gist_ncar_r', shrink=1, rotation=45)
fig = plt.gcf()
fig.set_size_inches(10, 8)
#plt.savefig('103_05-12_ellipses_cc_all_curv1.png', dpi=500, bbox_inches='tight', pad_inches=0.2)
plt.gcf().get_axes()[0].invert_yaxis();

# %%
h = heatmap.Heatmap(rslt)
h.plot(vmin=0.0, vmax=1.1, cmap='cubehelix')
fig = plt.gcf()
fig.set_size_inches(22, 18)

plt.gcf().get_axes()[1].invert_xaxis();
#plt.gcf().get_axes()[1].invert_yaxis()
#plt.gcf().get_axes()[2].invert_yaxis()

# %% [markdown]
# #### SEABORN CLUSTERING

# %%
g = sns.clustermap(data.corr(), cmap="mako", metric='correlation', method = 'complete', robust='True',  standard_scale =1) 
fig = plt.gcf()
fig.set_size_inches(18, 18)
plt.gcf().get_axes()[1].invert_xaxis()
plt.gcf().get_axes()[2].invert_xaxis();

# %% [markdown]
# #### SEABORN CLUSTERING with distance correlation matrix

# %%
distcorr = lambda column1, column2: dcor.distance_correlation(column1, column2)
rslt = data.apply(lambda col1: data.apply(lambda col2: distcorr(col1, col2)))
pd.options.display.float_format = '{:,.2f}'.format
rslt
# Out:
#                      Position  Gross pay  Phi-h  Pressure  Random 1  Random 2  \
# Position                 1.00       0.28   0.32      0.22      0.32      0.54
# Gross pay                0.28       1.00   0.89      0.34      0.32      0.45
# Phi-h                    0.32       0.89   1.00      0.27      0.35      0.54
# Pressure                 0.22       0.34   0.27      1.00      0.27      0.31
# Random 1                 0.32       0.32   0.35      0.27      1.00      0.23
# Random 2                 0.54       0.45   0.54      0.31      0.23      1.00
# Gross pay transform      0.23       0.97   0.83      0.38      0.35      0.39
#
#                      Gross pay transform
# Position                            0.23
# Gross pay                           0.97
# Phi-h                               0.83
# Pressure                            0.38
# Random 1                            0.35
# Random 2                            0.39
# Gross pay transform                 1.00

# %%
g = sns.clustermap(rslt, cmap="mako",  standard_scale =1) 
fig = plt.gcf()
fig.set_size_inches(18, 18)
plt.gcf().get_axes()[2].invert_yaxis();

# %% [markdown]
# __https://github.com/mwaskom/seaborn/issues/1207#issuecomment-424920950__

# %%
help(g.dendrogram_col)
# Out:
# Help on _DendrogramPlotter in module seaborn.matrix object:
#
# class _DendrogramPlotter(builtins.object)
#  |  Object for drawing tree of similarities between data rows/columns
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, data, linkage, metric, method, axis, label, rotate)
#  |      Plot a dendrogram of the relationships between the columns of data
#  |
#  |      Parameters
#  |      ----------
#  |      data : pandas.DataFrame
#  |          Rectangular data
#  |
#  |  calculate_dendrogram(self)
#  |      Calculates a dendrogram based on the linkage matrix
#  |
#  |      Made a separate function, not a property because don't want to
#  |      recalculate the dendrogram every time it is accessed.
#  |
#  |      Returns
#  |      -------
#  |      dendrogram : dict
#  |          Dendrogram dictionary as returned by scipy.cluster.hierarchy
#  |          .dendrogram. The important key-value pairing is
#  |          "reordered_ind" which indicates the re-ordering of the matrix
#  |
#  |  plot(self, ax)
#  |      Plots a dendrogram of the similarities between data on the axes
#  |
#  |      Parameters
#  |      ----------
#  |      ax : matplotlib.axes.Axes
#  |          Axes object upon which the dendrogram is plotted
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  calculated_linkage
#  |
#  |  reordered_ind
#  |      Indices of the matrix, reordered by the dendrogram

# %%
print (g.dendrogram_row.reordered_ind)
# Out:
# [2, 1, 6, 0, 5, 3, 4]

# %%
print (g.dendrogram_col.reordered_ind)
# Out:
# [2, 1, 6, 0, 5, 3, 4]

# %%
a = g.dendrogram_col.reordered_ind
a
# Out:
# [2, 1, 6, 0, 5, 3, 4]

# %%
[b[i] for i in a]
# Out:
# ['Phi-h',
#  'Gross pay',
#  'Gross pay transform',
#  'Position',
#  'Random 2',
#  'Pressure',
#  'Random 1']

# %%
data = data[[b[i] for i in a]]
data
# Out:
#     Phi-h  Gross pay  Gross pay transform  Position  Random 2  Pressure  \
# 0    0.50       0.10                 3.54      2.10       379        19
# 1    4.00       1.00                 5.79      1.10       269        16
# 2   19.00       1.90                 8.51      1.00       245        14
# 3   21.70       3.10                11.52      2.10       273        17
# 4   24.60       4.10                10.16      2.90       237        11
# 5   39.20       4.90                11.14      1.10       278        12
# 6   23.60       5.90                15.04      2.10       241        13
# 7   63.00       7.00                15.10      2.00       269        13
# 8   72.90       8.10                14.49      2.90       248        14
# 9   35.60       8.90                16.90      2.80       210        16
# 10 100.00      10.00                16.61      2.20       334        16
# 11  77.70      11.10                17.81      2.00       340        14
# 12  71.40      11.90                19.74      2.90       224        20
# 13 117.00      13.00                17.70      1.10       338        16
# 14 141.00      14.10                19.16      1.20       367        14
# 15 105.70      15.10                21.97      1.00       363        17
# 16  79.50      15.90                22.15      1.10       395        20
# 17 160.00      16.00                24.24      1.20       295        17
# 18  85.50      17.10                23.58      1.90       266        14
# 19  90.00      18.00                23.77      2.80       210        18
# 20 114.60      19.10                29.25      2.10       366        10
#
#     Random 1
# 0          5
# 1         13
# 2         12
# 3          6
# 4         10
# 5          7
# 6         13
# 7         20
# 8          1
# 9          1
# 10        21
# 11         1
# 12        11
# 13         9
# 14        10
# 15         3
# 16        10
# 17        15
# 18         6
# 19        19
# 20        21

# %%
plt.rcParams["axes.labelsize"] = 18
g = sns.PairGrid(data, diag_sharey=False)
axes = g.axes

g.map_upper(plt.scatter,  linewidths=1, edgecolor="w", s=90, alpha = 0.5)
g.map_upper(corrfunc)

g.map_diag(sns.kdeplot, lw = 4, legend=False)
g.map_lower(sns.kdeplot, cmap="Blues_d")

#plt.savefig('matrix_final.png', dpi=500, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
sns.set()
g = sns.clustermap(data, cmap="mako", figsize=(15,15), metric='euclidean', method = 'complete', robust='True',  standard_scale =1) 


#g = sns.clustermap(data, cmap="mako", figsize=(15,15), metric='euclidean', method = 'complete', robust='True',  row_cluster = 'false', standard_scale =1)

# %% [markdown]
# ### Try this:
#
# https://seaborn.pydata.org/examples/structured_heatmap.html
