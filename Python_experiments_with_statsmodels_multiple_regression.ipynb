# %% [markdown]
# #### PRELIMINARIES

# %% [markdown]
# First we import the libraries we will need, and the data.

# %%
import matplotlib.pyplot as plt
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
import statsmodels.api as sm

# %matplotlib inline
# Out:
# /anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# #### Import data

# %%
data = pd.read_csv('Table2_Hunt_2013_edit.csv')
data = data.drop(['Random 1', 'Random 2', 'Gross pay transform'],  axis=1)

# %%
data
# Out:
#     Gross pay  Phi-h  Position  Pressure  Production
# 0         0.1    0.5       2.1        19       15.10
# 1         1.0    4.0       1.1        16       21.30
# 2         1.9   19.0       1.0        14       22.75
# 3         3.1   21.7       2.1        17       15.72
# 4         4.1   24.6       2.9        11        7.71
# 5         4.9   39.2       1.1        12       22.67
# 6         5.9   23.6       2.1        13       18.11
# 7         7.0   63.0       2.0        13       24.30
# 8         8.1   72.9       2.9        14       24.04
# 9         8.9   35.6       2.8        16       25.11
# 10       10.0  100.0       2.2        16       36.80
# 11       11.1   77.7       2.0        14       36.42
# 12       11.9   71.4       2.9        20       39.59
# 13       13.0  117.0       1.1        16       51.60
# 14       14.1  141.0       1.2        14       48.05
# 15       15.1  105.7       1.0        17       51.72
# 16       15.9   79.5       1.1        20       59.20
# 17       16.0  160.0       1.2        17       58.30
# 18       17.1   85.5       1.9        14       41.80
# 19       18.0   90.0       2.8        18       44.20
# 20       19.1  114.6       2.1        10       37.51

# %% [markdown]
# A quick summary of the data (count row) shows there are no missing data points.

# %%
data.describe()
# Out:
#        Gross pay       Phi-h   Position   Pressure  Production
# count  21.000000   21.000000  21.000000  21.000000   21.000000
# mean    9.823810   68.880952   1.885714  15.285714   33.428571
# std     5.948521   45.167894   0.708721   2.759400   15.141909
# min     0.100000    0.500000   1.000000  10.000000    7.710000
# 25%     4.900000   24.600000   1.100000  14.000000   22.670000
# 50%    10.000000   72.900000   2.000000  16.000000   36.420000
# 75%    15.100000  100.000000   2.200000  17.000000   44.200000
# max    19.100000  160.000000   2.900000  20.000000   59.200000

# %% [markdown]
# We can also explicitly test to ensure data does not have no missing measurements.

# %%
data.isnull().values.any()
# Out:
# False

# %% [markdown]
# #### Multiple regression

# %% [markdown]
# 1) Ordinary Least Square in Statsmodels
#
# 2) Linear Regression fit in Scikit-learn

# %%
X = data.loc[:,'Gross pay':'Pressure']
y = data.loc[:,'Production']

# %% [markdown]
# ##### Ordinary Least Square in Statsmodels

# %%
model = sm.OLS(y, sm.add_constant(X))
results = model.fit()
print (results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Production   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.977
# Method:                 Least Squares   F-statistic:                     211.1
# Date:                Mon, 16 Apr 2018   Prob (F-statistic):           1.27e-13
# Time:                        19:56:47   Log-Likelihood:                -44.514
# No. Observations:                  21   AIC:                             99.03
# Df Residuals:                      16   BIC:                             104.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.7089      3.454     -0.495      0.627      -9.031       5.613
# Gross pay      1.3682      0.177      7.747      0.000       0.994       1.743
# Phi-h          0.1068      0.024      4.508      0.000       0.057       0.157
# Position      -6.6575      0.783     -8.504      0.000      -8.317      -4.998
# Pressure       1.7594      0.189      9.303      0.000       1.358       2.160
# ==============================================================================
# Omnibus:                        1.909   Durbin-Watson:                   1.916
# Prob(Omnibus):                  0.385   Jarque-Bera (JB):                1.136
# Skew:                          -0.569   Prob(JB):                        0.567
# Kurtosis:                       2.973   Cond. No.                         577.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
print(results.params)
# Out:
# const       -1.708930
# Gross pay    1.368181
# Phi-h        0.106817
# Position    -6.657512
# Pressure     1.759371
# dtype: float64

# %%
r = results.rsquared**0.5
p = results.f_pvalue

# %%
fig = plt.figure(figsize=(8,8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(results.predict(), y, s = 60, color="darkslategray")

ax1.set_ylabel('Production', fontsize = '14')
ax1.set_xlim([0, 65])
ax1.set_ylim([0, 65])
ax1.set_xlabel('OLS multivariate regression', fontsize = '14')

ax1.annotate("r = {:.4f}".format(r), xy=(4, 55))
ax1.annotate("p = {:.3f}".format(p), xy=(15, 55));

# %%
rsl = results.get_prediction()

[method_name for method_name in dir(rsl)
 if callable(getattr(rsl, method_name))]
# Out:
# ['__class__',
#  '__delattr__',
#  '__dir__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'conf_int',
#  'dist',
#  'summary_frame']

# %%
print (rsl.conf_int().T[0])        # lower CI
print (rsl.conf_int(obs=True).T[0]) # lower PI

print (rsl.conf_int().T[1])         # upper CI
print (rsl.conf_int(obs=True).T[1]) # upper PI
# Out:
# [15.25047254 18.41940688 18.50628739 18.93106243  3.91973641 20.65897995
#  15.93537454 22.5659432  20.1183334  21.80720016 34.04905147 31.86441428
#  35.35445127 47.44393828 46.77243525 51.4222193  53.27964091 56.23753412
#  40.38456507 42.84604361 37.11991558]
# [12.34926864 15.4199823  15.4480256  15.547178    1.00642166 17.55821843
#  12.54635255 19.00872395 17.04816407 18.50252215 30.82846583 28.04720349
#  32.47767211 44.13016414 43.78369619 48.17843462 50.59602261 53.47539365
#  37.34289786 39.9631566  34.45284697]
# [20.60665968 23.40697264 23.28135602 22.62672685  9.22948616 25.28418347
#  19.61516921 25.74330323 24.85111318 25.75175339 38.26698097 34.32308826
#  40.80517093 51.35949663 51.79924206 55.56375069 59.52291621 62.1485134
#  45.21896498 48.2730123  43.43513372]
# [23.50786358 26.40639721 26.3396178  26.01061127 12.14280091 28.38494499
#  23.0041912  29.30052248 27.92128251 29.0564314  41.48756662 38.14029905
#  43.68195009 54.67327077 54.78798112 58.80753537 62.20653452 64.91065387
#  48.26063219 51.15589931 46.10220233]

# %%
rsl.summary_frame()
# Out:
#          mean   mean_se  mean_ci_lower  mean_ci_upper  obs_ci_lower  \
# 0   17.928566  1.263308      15.250473      20.606660     12.349269
# 1   20.913190  1.176365      18.419407      23.406973     15.419982
# 2   20.893822  1.126246      18.506287      23.281356     15.448026
# 3   20.778895  0.871658      18.931062      22.626727     15.547178
# 4    6.574611  1.252355       3.919736       9.229486      1.006422
# 5   22.971582  1.090899      20.658980      25.284183     17.558218
# 6   17.775272  0.867915      15.935375      19.615169     12.546353
# 7   24.154623  0.749411      22.565943      25.743303     19.008724
# 8   22.484723  1.116272      20.118333      24.851113     17.048164
# 9   23.779477  0.930361      21.807200      25.751753     18.502522
# 10  36.158016  0.994839      34.049051      38.266981     30.828466
# 11  33.093751  0.579902      31.864414      34.323088     28.047203
# 12  38.079811  1.285605      35.354451      40.805171     32.477672
# 13  49.401717  0.923522      47.443938      51.359497     44.130164
# 14  49.285839  1.185621      46.772435      51.799242     43.783696
# 15  53.492985  0.976820      51.422219      55.563751     48.178435
# 16  56.401279  1.472536      53.279641      59.522916     50.596023
# 17  59.193024  1.394161      56.237534      62.148513     53.475394
# 18  42.801765  1.140240      40.384565      45.218965     37.342898
# 19  45.559528  1.280003      42.846044      48.273012     39.963157
# 20  40.277525  1.489505      37.119916      43.435134     34.452847
#
#     obs_ci_upper
# 0      23.507864
# 1      26.406397
# 2      26.339618
# 3      26.010611
# 4      12.142801
# 5      28.384945
# 6      23.004191
# 7      29.300522
# 8      27.921283
# 9      29.056431
# 10     41.487567
# 11     38.140299
# 12     43.681950
# 13     54.673271
# 14     54.787981
# 15     58.807535
# 16     62.206535
# 17     64.910654
# 18     48.260632
# 19     51.155899
# 20     46.102202

# %%
data['obs_pi_lower'] = rsl.summary_frame()['obs_ci_lower'] 
data['obs_pi_upper'] = rsl.summary_frame()['obs_ci_upper']

data['prediction'] = results.predict()
#data['prediction'] = rsl.summary_frame(['mean']) # would be the same
data.describe()
# Out:
#        Gross pay       Phi-h   Position   Pressure  Production  obs_pi_lower  \
# count  21.000000   21.000000  21.000000  21.000000   21.000000     21.000000
# mean    9.823810   68.880952   1.885714  15.285714   33.428571     27.986229
# std     5.948521   45.167894   0.708721   2.759400   15.141909     14.932282
# min     0.100000    0.500000   1.000000  10.000000    7.710000      1.006422
# 25%     4.900000   24.600000   1.100000  14.000000   22.670000     15.547178
# 50%    10.000000   72.900000   2.000000  16.000000   36.420000     28.047203
# 75%    15.100000  100.000000   2.200000  17.000000   44.200000     39.963157
# max    19.100000  160.000000   2.900000  20.000000   59.200000     53.475394
#
#        obs_pi_upper  prediction
# count     21.000000   21.000000
# mean      38.870914   33.428571
# std       15.071133   15.000427
# min       12.142801    6.574611
# 25%       26.406397   20.913190
# 50%       38.140299   33.093751
# 75%       51.155899   45.559528
# max       64.910654   59.193024

# %%
data
# Out:
#     Gross pay  Phi-h  Position  Pressure  Production  obs_pi_lower  \
# 0         0.1    0.5       2.1        19       15.10     12.349269
# 1         1.0    4.0       1.1        16       21.30     15.419982
# 2         1.9   19.0       1.0        14       22.75     15.448026
# 3         3.1   21.7       2.1        17       15.72     15.547178
# 4         4.1   24.6       2.9        11        7.71      1.006422
# 5         4.9   39.2       1.1        12       22.67     17.558218
# 6         5.9   23.6       2.1        13       18.11     12.546353
# 7         7.0   63.0       2.0        13       24.30     19.008724
# 8         8.1   72.9       2.9        14       24.04     17.048164
# 9         8.9   35.6       2.8        16       25.11     18.502522
# 10       10.0  100.0       2.2        16       36.80     30.828466
# 11       11.1   77.7       2.0        14       36.42     28.047203
# 12       11.9   71.4       2.9        20       39.59     32.477672
# 13       13.0  117.0       1.1        16       51.60     44.130164
# 14       14.1  141.0       1.2        14       48.05     43.783696
# 15       15.1  105.7       1.0        17       51.72     48.178435
# 16       15.9   79.5       1.1        20       59.20     50.596023
# 17       16.0  160.0       1.2        17       58.30     53.475394
# 18       17.1   85.5       1.9        14       41.80     37.342898
# 19       18.0   90.0       2.8        18       44.20     39.963157
# 20       19.1  114.6       2.1        10       37.51     34.452847
#
#     obs_pi_upper  prediction
# 0      23.507864   17.928566
# 1      26.406397   20.913190
# 2      26.339618   20.893822
# 3      26.010611   20.778895
# 4      12.142801    6.574611
# 5      28.384945   22.971582
# 6      23.004191   17.775272
# 7      29.300522   24.154623
# 8      27.921283   22.484723
# 9      29.056431   23.779477
# 10     41.487567   36.158016
# 11     38.140299   33.093751
# 12     43.681950   38.079811
# 13     54.673271   49.401717
# 14     54.787981   49.285839
# 15     58.807535   53.492985
# 16     62.206535   56.401279
# 17     64.910654   59.193024
# 18     48.260632   42.801765
# 19     51.155899   45.559528
# 20     46.102202   40.277525

# %%
fig = plt.figure(figsize=(8,8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(results.predict(), y, s = 60, color="darkslategray")

ax1.plot(np.arange(0, max(y), dtype = int), np.arange(0, max(y), dtype = int), '-', lw=2, color="k")
ax1.set_ylabel('Production', fontsize = '14')
ax1.set_xlabel('OLS multiple regression', fontsize = '14')

#ax1.plot(results.predict(), rsl.conf_int(obs=True).T[0], 'r--')
#ax1.plot(results.predict(), rsl.conf_int(obs=True).T[1], 'r--')

ax1.scatter(results.predict(), rsl.conf_int(obs=True).T[0], marker = '.', s = 35, color="r")
ax1.scatter(results.predict(), rsl.conf_int(obs=True).T[1], marker = '.', s = 35, color="r");

# %%
data = data.sort_values('Production')

# %%
data
# Out:
#     Gross pay  Phi-h  Position  Pressure  Production  obs_pi_lower  \
# 4         4.1   24.6       2.9        11        7.71      1.006422
# 0         0.1    0.5       2.1        19       15.10     12.349269
# 3         3.1   21.7       2.1        17       15.72     15.547178
# 6         5.9   23.6       2.1        13       18.11     12.546353
# 1         1.0    4.0       1.1        16       21.30     15.419982
# 5         4.9   39.2       1.1        12       22.67     17.558218
# 2         1.9   19.0       1.0        14       22.75     15.448026
# 8         8.1   72.9       2.9        14       24.04     17.048164
# 7         7.0   63.0       2.0        13       24.30     19.008724
# 9         8.9   35.6       2.8        16       25.11     18.502522
# 11       11.1   77.7       2.0        14       36.42     28.047203
# 10       10.0  100.0       2.2        16       36.80     30.828466
# 20       19.1  114.6       2.1        10       37.51     34.452847
# 12       11.9   71.4       2.9        20       39.59     32.477672
# 18       17.1   85.5       1.9        14       41.80     37.342898
# 19       18.0   90.0       2.8        18       44.20     39.963157
# 14       14.1  141.0       1.2        14       48.05     43.783696
# 13       13.0  117.0       1.1        16       51.60     44.130164
# 15       15.1  105.7       1.0        17       51.72     48.178435
# 17       16.0  160.0       1.2        17       58.30     53.475394
# 16       15.9   79.5       1.1        20       59.20     50.596023
#
#     obs_pi_upper  prediction
# 4      12.142801    6.574611
# 0      23.507864   17.928566
# 3      26.010611   20.778895
# 6      23.004191   17.775272
# 1      26.406397   20.913190
# 5      28.384945   22.971582
# 2      26.339618   20.893822
# 8      27.921283   22.484723
# 7      29.300522   24.154623
# 9      29.056431   23.779477
# 11     38.140299   33.093751
# 10     41.487567   36.158016
# 20     46.102202   40.277525
# 12     43.681950   38.079811
# 18     48.260632   42.801765
# 19     51.155899   45.559528
# 14     54.787981   49.285839
# 13     54.673271   49.401717
# 15     58.807535   53.492985
# 17     64.910654   59.193024
# 16     62.206535   56.401279

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(np.arange(21), data['Production']);

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(data['prediction'], data['Production']);

# %%
data = data.sort_values('prediction')

# %%
data
# Out:
#     Gross pay  Phi-h  Position  Pressure  Production  obs_pi_lower  \
# 4         4.1   24.6       2.9        11        7.71      1.006422
# 6         5.9   23.6       2.1        13       18.11     12.546353
# 0         0.1    0.5       2.1        19       15.10     12.349269
# 3         3.1   21.7       2.1        17       15.72     15.547178
# 2         1.9   19.0       1.0        14       22.75     15.448026
# 1         1.0    4.0       1.1        16       21.30     15.419982
# 8         8.1   72.9       2.9        14       24.04     17.048164
# 5         4.9   39.2       1.1        12       22.67     17.558218
# 9         8.9   35.6       2.8        16       25.11     18.502522
# 7         7.0   63.0       2.0        13       24.30     19.008724
# 11       11.1   77.7       2.0        14       36.42     28.047203
# 10       10.0  100.0       2.2        16       36.80     30.828466
# 12       11.9   71.4       2.9        20       39.59     32.477672
# 20       19.1  114.6       2.1        10       37.51     34.452847
# 18       17.1   85.5       1.9        14       41.80     37.342898
# 19       18.0   90.0       2.8        18       44.20     39.963157
# 14       14.1  141.0       1.2        14       48.05     43.783696
# 13       13.0  117.0       1.1        16       51.60     44.130164
# 15       15.1  105.7       1.0        17       51.72     48.178435
# 16       15.9   79.5       1.1        20       59.20     50.596023
# 17       16.0  160.0       1.2        17       58.30     53.475394
#
#     obs_pi_upper  prediction
# 4      12.142801    6.574611
# 6      23.004191   17.775272
# 0      23.507864   17.928566
# 3      26.010611   20.778895
# 2      26.339618   20.893822
# 1      26.406397   20.913190
# 8      27.921283   22.484723
# 5      28.384945   22.971582
# 9      29.056431   23.779477
# 7      29.300522   24.154623
# 11     38.140299   33.093751
# 10     41.487567   36.158016
# 12     43.681950   38.079811
# 20     46.102202   40.277525
# 18     48.260632   42.801765
# 19     51.155899   45.559528
# 14     54.787981   49.285839
# 13     54.673271   49.401717
# 15     58.807535   53.492985
# 16     62.206535   56.401279
# 17     64.910654   59.193024

# %%
fig = plt.figure(figsize=(8,8))
plt.plot(data['prediction'], data['Production']);

# %%
fig = plt.figure(figsize=(8,8))

ax1 = fig.add_subplot(1, 1, 1)
ax1.scatter(data['prediction'], data['Production'], s = 60, color="darkslategray")



ax1.set_ylabel('Production', fontsize = '14')
ax1.set_xlabel('OLS multiple regression', fontsize = '14')

ax1.plot(data['prediction'], data['obs_pi_upper'], 'g--', label = "upper PI")
ax1.plot(data['prediction'], data['obs_pi_lower'], 'm--', label = "lower PI")
ax1.set_xlim([0,65])
ax1.set_ylim([0,70])

plt.legend();
